# %% [markdown]
# # 18th April 2026

# %%
var = lambda a,b: a + b
print(var(5, 10))
# Out:
# 15

# %%
scores=[34,55,88,90,67]
max_marks=120

percetnage = list(map(lambda x:x*100/max_marks, scores))
print(percetnage)
# Out:
# [28.333333333333332, 45.833333333333336, 73.33333333333333, 75.0, 55.833333333333336]

# %%
Input = [1,2,3,4,5]
output = list(filter(lambda x:x%2==0,Input))
output = list(map(lambda x:x**2,output))
print(output)
# Out:
# [4, 16]
